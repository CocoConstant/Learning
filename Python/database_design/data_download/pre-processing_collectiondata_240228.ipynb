# %%
import pandas as pd

pbmc_df = pd.read_csv("/mnt/d/dailywork/PBMC_database/TrueBlood_240228.csv")

# %%
pbmc_df.head()
# Out:
#          PMID                                               数据信息  \
# 0  33657410.0                                          GSE158055
# 1  37597510.0  GSE196988;196990,GSE196989;196990,GSE196989,GS...
# 2  37607536.0                                                NaN
# 3  37593735.0                                                NaN
# 4  32554932.0                                          GSE151263
#
#                                                Title   备注  \
# 0  COVID-19 immune features revealed by a large-s...  NaN
# 1  Epigenetic memory of coronavirus infection in ...  NaN
# 2  A pan-cancer single-cell panorama of human nat...  NaN
# 3  Single-cell RNA sequencing reveals the transcr...  NaN
# 4  Single cell RNA sequencing identifies an early...  NaN
#
#                                         Article File supplemental_file  \
# 0                           PIIS0092867421001483.pdf               NaN
# 1  20230818_Epigenetic memory of coronavirus infe...               NaN
# 2  A pan-cancer single-cell panorama of human nat...               NaN
# 3                                     乙型肝炎疫苗pbmc.pdf               NaN
# 4  135678.2-20200707154530-covered-e0fd13ba177f91...               NaN
#
#     Project_ID                         DOI  \
# 0  PRJNA663865  10.1016/j.cell.2021.01.053
# 1  PRJNA808241  10.1016/j.cell.2023.07.019
# 2  PRJNA877828  10.1016/j.cell.2023.07.034
# 3  PRJNA954417  10.3389/fimmu.2023.1091237
# 4  PRJNA635353  10.1172/jci.insight.135678
#
#                                  Journal Publish_date  ...  \
# 0                                   Cell   2021/02/03  ...
# 1                                   Cell   2023/08/18  ...
# 2                                   Cell   2023/08/21  ...
# 3                Frontiers in Immunology   2023/08/01  ...
# 4  The Journal of Clinical Investigation   2020/06/18  ...
#
#                       Disease  \
# 0                    COVID-19
# 1                    COVID-19
# 2                         NaN
# 3                 hepatitis B
# 4  acute respiratory distress
#
#                                         Data_summary  \
# 0  We profiled scRNA-seq of 284 samples collected...
# 1  Inflammation can trigger lasting phenotypes in...
# 2  Natural killer (NK) cells play indispensable r...
# 3  The emergence of a vaccine against hepatitis B...
# 4  The acute respiratory distress syndrome (ARDS)...
#
#                                  Data_overall_design Data_availability  \
# 0  Multiple types of tissues from healthy individ...                公开
# 1                                                NaN                公开
# 2  We generated scRNA-seq data from 47 cancer pat...                公开
# 3  Single-cell RNA sequencing was performed on pe...                公开
# 4  7 Frozen PBMC samples, 4 with sepsis only, 3 w...                公开
#
#                                             Data_url 数据备注      update  负责人  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
#
#    文章信息状态 数据状态
# 0     待检查  待收集
# 1     待检查  待收集
# 2     待检查  待收集
# 3     待检查  待收集
# 4     待检查  待收集
#
# [5 rows x 37 columns]

# %%
pbmc_df.shape
# Out:
# (130, 37)

# %%
pbmc_df.columns
# Out:
# Index(['PMID', '数据信息', 'Title', '备注', 'Article File', 'supplemental_file',
#        'Project_ID', 'DOI', 'Journal', 'Publish_date', 'Contributors',
#        'Picture', 'Contact', 'Institution', 'Literature_url', 'DOI_URL',
#        'Country', 'Biosample', 'Sample_count', 'Sample_depict', 'Min_age',
#        'Max_age', 'scRNA-seq_cells', 'scATAC-seq_cells', 'Technology',
#        'Platform', 'Source', 'Disease', 'Data_summary', 'Data_overall_design',
#        'Data_availability', 'Data_url', '数据备注', 'update', '负责人', '文章信息状态',
#        '数据状态'],
#       dtype='object')

# %%
pbmc_df = pbmc_df[pbmc_df.文章信息状态 == "待检查"]
print(pbmc_df.shape)
pbmc_df.head(5)
# Out:
# (29, 37)
#          PMID                                               数据信息  \
# 0  33657410.0                                          GSE158055
# 1  37597510.0  GSE196988;196990,GSE196989;196990,GSE196989,GS...
# 2  37607536.0                                                NaN
# 3  37593735.0                                                NaN
# 4  32554932.0                                          GSE151263
#
#                                                Title   备注  \
# 0  COVID-19 immune features revealed by a large-s...  NaN
# 1  Epigenetic memory of coronavirus infection in ...  NaN
# 2  A pan-cancer single-cell panorama of human nat...  NaN
# 3  Single-cell RNA sequencing reveals the transcr...  NaN
# 4  Single cell RNA sequencing identifies an early...  NaN
#
#                                         Article File supplemental_file  \
# 0                           PIIS0092867421001483.pdf               NaN
# 1  20230818_Epigenetic memory of coronavirus infe...               NaN
# 2  A pan-cancer single-cell panorama of human nat...               NaN
# 3                                     乙型肝炎疫苗pbmc.pdf               NaN
# 4  135678.2-20200707154530-covered-e0fd13ba177f91...               NaN
#
#     Project_ID                         DOI  \
# 0  PRJNA663865  10.1016/j.cell.2021.01.053
# 1  PRJNA808241  10.1016/j.cell.2023.07.019
# 2  PRJNA877828  10.1016/j.cell.2023.07.034
# 3  PRJNA954417  10.3389/fimmu.2023.1091237
# 4  PRJNA635353  10.1172/jci.insight.135678
#
#                                  Journal Publish_date  ...  \
# 0                                   Cell   2021/02/03  ...
# 1                                   Cell   2023/08/18  ...
# 2                                   Cell   2023/08/21  ...
# 3                Frontiers in Immunology   2023/08/01  ...
# 4  The Journal of Clinical Investigation   2020/06/18  ...
#
#                       Disease  \
# 0                    COVID-19
# 1                    COVID-19
# 2                         NaN
# 3                 hepatitis B
# 4  acute respiratory distress
#
#                                         Data_summary  \
# 0  We profiled scRNA-seq of 284 samples collected...
# 1  Inflammation can trigger lasting phenotypes in...
# 2  Natural killer (NK) cells play indispensable r...
# 3  The emergence of a vaccine against hepatitis B...
# 4  The acute respiratory distress syndrome (ARDS)...
#
#                                  Data_overall_design Data_availability  \
# 0  Multiple types of tissues from healthy individ...                公开
# 1                                                NaN                公开
# 2  We generated scRNA-seq data from 47 cancer pat...                公开
# 3  Single-cell RNA sequencing was performed on pe...                公开
# 4  7 Frozen PBMC samples, 4 with sepsis only, 3 w...                公开
#
#                                             Data_url 数据备注      update  负责人  \
# 0  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 1  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 2  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 3  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
# 4  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...  NaN  2023/11/06  陈晓雅
#
#    文章信息状态 数据状态
# 0     待检查  待收集
# 1     待检查  待收集
# 2     待检查  待收集
# 3     待检查  待收集
# 4     待检查  待收集
#
# [5 rows x 37 columns]

# %%
batch_downl_df = pbmc_df[pbmc_df.数据信息 != ]
batch_downl_df.shape
# Out:
# (29, 37)

# %%
pbmc_df[pbmc_df["数据信息"].isna()]
# Out:
#           PMID 数据信息                                              Title  \
# 2   37607536.0  NaN  A pan-cancer single-cell panorama of human nat...
# 3   37593735.0  NaN  Single-cell RNA sequencing reveals the transcr...
# 6   34880454.0  NaN  Single-cell RNA sequencing reveals B cell–rela...
# 7   37414801.0  NaN  Single cell transcriptome sequencing of stimul...
# 13  32286271.0  NaN  Single-cell transcriptomics identifies an effe...
# 14  35213211.0  NaN  Single-cell eQTL analysis of activated T cell ...
# 15  35618845.0  NaN  Immune disease risk variants regulate gene exp...
# 16  33046887.0  NaN  Two subsets of stem-like CD8+ memory T cell pr...
# 18  35133977.0  NaN  Single-cell RNA sequencing reveals induction o...
# 19  34691592.0  NaN  Single-cell transcriptomic landscape of human ...
# 20  28428369.0  NaN  Single-cell RNA-seq reveals new types of human...
# 21  35672358.0  NaN  Single-cell RNA-sequencing of peripheral blood...
# 22  31719197.0  NaN  Single-cell transcriptomics reveals expansion ...
# 23  33271118.0  NaN  Comprehensive Profiling of an Aging Immune Sys...
# 25  34385315.0  NaN  Effects of sex and aging on the immune cell la...
# 27  37117750.0  NaN  Multidimensional single-cell analysis of human...
# 28  37379396.0  NaN  Human PBMC scRNA-seq–based aging clocks reveal...
# 31  32425270.0  NaN  Potent Neutralizing Antibodies against SARS-Co...
# 32  34108657.0  NaN  Single-cell epigenomic landscape of peripheral...
# 33  29352091.0  NaN  Precursors of human CD4+ cytotoxic T lymphocyt...
# 35  32595980.0  NaN  Immune cell profiling of COVID-19 patients in ...
#
#                                                    备注  \
# 2                                                 NaN
# 3                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 13                          EGAS00001003215\n数据信息列不能填
# 14   In a larger sample size study sorted and acti...
# 15                                    EGAD00001008197
# 16                      GSE147398\nbulkRNA with scRNA
# 18                                                NaN
# 19                                                NaN
# 20
# 21                                                NaN
# 22  Intriguingly, extensive research has identifie...
# 23  其他文章age-associated expansion of granzyme K (GZ...
# 25  The main variations of cellular composition ar...
# 27  Another study added the cord blood and PBMC of...
# 28                                                NaN
# 31  The scRNA-seq technology also helps to find po...
# 32  In convalescent patients of COVID-19 disease, ...
# 33  Interestingly, the protective CD4+ CTL mention...
# 35
#
#                                          Article File supplemental_file  \
# 2   A pan-cancer single-cell panorama of human nat...               NaN
# 3                                      乙型肝炎疫苗pbmc.pdf               NaN
# 6                                    B_cell阿尔兹海默症.pdf               NaN
# 7                              s41597-023-02348-z.pdf               NaN
# 13                             s41467-020-15543-y.pdf               NaN
# 14                                  nihms-1793110.pdf               NaN
# 15                             s41588-022-01066-3.pdf               NaN
# 16                              s41590-020-0791-5.pdf               NaN
# 18                                 jci-132-147719.pdf               NaN
# 19                                        nwaa180.pdf               NaN
# 20                                    nihms910854.pdf               NaN
# 21                             s41467-022-30893-5.pdf               NaN
# 22  hashimoto-et-al-2019-single-cell-transcriptomi...               NaN
# 23                           PIIS1074761320304921.pdf               NaN
# 25  huang-et-al-2021-effects-of-sex-and-aging-on-t...               NaN
# 27                             s43587-022-00198-9.pdf               NaN
# 28                                 sciadv.abq7599.pdf               NaN
# 31                           PIIS0092867420306206.pdf               NaN
# 32                           PIIS0092867420306206.pdf               NaN
# 33                                    nihms959730.pdf               NaN
# 35                              s41421-020-0168-9.pdf               NaN
#
#        Project_ID                           DOI  \
# 2     PRJNA877828    10.1016/j.cell.2023.07.034
# 3     PRJNA954417    10.3389/fimmu.2023.1091237
# 6     PRJNA708200    10.1038/s12276-021-00714-8
# 7     PRJNA940428    10.1038/s41597-023-02348-z
# 13            NaN    10.1038/s41467-020-15543-y
# 14            NaN    10.1126/sciimmunol.abm2508
# 15            NaN    10.1038/s41588-022-01066-3
# 16    PRJNA614476     10.1038/s41590-020-0791-5
# 18            NaN             10.1172/JCI147719
# 19  \nPRJNA593188           10.1093/nsr/nwaa180
# 20    PRJNA374527       10.1126/science.aah4573
# 21            NaN    10.1038/s41467-022-30893-5
# 22            NaN       10.1073/pnas.1907883116
# 23    PRJNA648132  10.1016/j.immuni.2020.11.005
# 25    PRJCA003693       10.1073/pnas.2023216118
# 27    PRJNA659762    10.1038/s43587-022-00198-9
# 28    PRJNA881281        10.1126/sciadv.abq7599
# 31            NaN    10.1016/j.cell.2020.05.025
# 32    PRJNA718009    10.1038/s41556-021-00690-1
# 33    PRJNA417187    10.1126/sciimmunol.aan8664
# 35            NaN     10.1038/s41421-020-0168-9
#
#                                   Journal Publish_date  ...  \
# 2                                    Cell   2023/08/21  ...
# 3                 Frontiers in Immunology   2023/08/01  ...
# 6       Experimental & Molecular Medicine   2021/12/08  ...
# 7                         Scientific Data   2023/07/06  ...
# 13                  Nature Communications   2020/04/14  ...
# 14                     Science Immunology   2022/02/25  ...
# 15                        Nature genetics   2022/05/26  ...
# 16                      Nature immunology   2020/10/12  ...
# 18  The Journal of Clinical Investigation   2022/04/01  ...
# 19                National Science Review   2020/07/31  ...
# 20                                Science   2017/04/21  ...
# 21                  Nature Communications          NaN  ...
# 22                                   PNAS   2019/11/26  ...
# 23                               Immunity   2021/01/12  ...
# 25                                   PNAS   2021/08/12  ...
# 27                           Nature Aging   2022/04/18  ...
# 28                       Science Advances   2023/06/28  ...
# 31                                   Cell   2020/07/09  ...
# 32                    Nature Cell Biology   2021/01/09  ...
# 33                     Science Immunology   2018/07/19  ...
# 35                         Cell Discovery   2020/03/04  ...
#
#                       Disease  \
# 2                         NaN
# 3                 hepatitis B
# 6         Alzheimer’s disease
# 7                         NaN
# 13                    Healthy
# 14                    Healthy
# 15                    Healthy
# 16                    Healthy
# 18                    Healthy
# 19                    Healthy
# 20                    Healthy
# 21                    Healthy
# 22           supercentenarian
# 23                    Healthy
# 25                    Healthy
# 27                    Healthy
# 28  Healthy, supercentenarian
# 31                   COVID-19
# 32          COVID-19, Healthy
# 33                        NaN
# 35                   COVID-19
#
#                                          Data_summary  \
# 2   Natural killer (NK) cells play indispensable r...
# 3   The emergence of a vaccine against hepatitis B...
# 6   In the current study, differentially expressed...
# 7   Peripheral blood mononuclear cells (PBMCs) are...
# 13  we isolated TN and TM from four healthy indivi...
# 14                                                NaN
# 15  We isolated and stimulated naive and memory CD...
# 16  We initially used single-cell RNA sequencing t...
# 18  scRNAseq of monocytes from in vitro Trained im...
# 19  We profiled the transcriptomes of 7,643 human ...
# 20  Peripheral blood mononuclear cells (PBMCs) wer...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 25                                                NaN
# 27  Frailty is an intermediate status of human age...
# 28  Quantifying aging rate is important for evalua...
# 31                                                NaN
# 32  Here, we applied assay of single-cell transpos...
# 33                                                NaN
# 35                                                NaN
#
#                                   Data_overall_design Data_availability  \
# 2   We generated scRNA-seq data from 47 cancer pat...                公开
# 3   Single-cell RNA sequencing was performed on pe...                公开
# 6   Single-cell RNA sequencing analysis of PBMCs f...                公开
# 7   We performed single-cell gene expression profi...                公开
# 13                                                NaN                受控
# 14                                                NaN               NaN
# 15                                                NaN                受控
# 16                                                NaN                公开
# 18                                                NaN                公开
# 19  Single cell RNAseq for BM/PB-derived 32 blood ...                受控
# 20  The study was divided into two stages: (1) an ...                公开
# 21  Here we present the 1M-scBloodNL study, in whi...                受控
# 22                                                NaN                受控
# 23                                                NaN                公开
# 25  Difference in immune function roots from multi...                受控
# 27  Three cord blood samples, PBMC samples from 3 ...                公开
# 28  All volunteers were evaluated as generally hea...                公开
# 31                                                NaN                受控
# 32                                                NaN                受控
# 33                             详情见GSE106544，含有每个样本的描述               NaN
# 35                                                NaN               NaN
#
#                                              Data_url  \
# 2   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 6   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 7   https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 13  https://www.opentargets.org/projects/effectorness
# 14                           http://dice-database.org
# 15   https://ega-archive.org/datasets/EGAD00001008197
# 16  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 18  https://www.ebi.ac.uk/biostudies/arrayexpress/...
# 19  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 20                   http://www.ncbi.nlm.nih.gov/gap;
# 21    https://ega-archive.org/studies/EGAS00001005376
# 22                   http://gerg.gsc.riken.jp/SC2018/
# 23  https://www.synapse.org/#!Synapse:syn22255433/...
# 25  https://ngdc.cncb.ac.cn/gsa-human/browse/HRA00...
# 27  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 28     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi
# 31                                         http://需联系
# 32  https://ngdc.cncb.ac.cn/gsa-human/browse/HRA00...
# 33  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 35                                                NaN
#
#                                                  数据备注      update  负责人  \
# 2                                                 NaN  2023/11/06  陈晓雅
# 3                                                 NaN  2023/11/06  陈晓雅
# 6                                                 NaN  2023/11/06  陈晓雅
# 7                                                 NaN  2023/11/06  陈晓雅
# 13                    文章自测数据量较少，而且只测了T细胞。需要获取EGA数据库权限  2024/01/31  欧阳康
# 14                                                NaN  2024/01/04  陈晓雅
# 15                                        需要申请EGA数据权限  2024/02/01  欧阳康
# 16            ATAC数据受控，且文章中未描述数量。其他数据均为混样，部分数据来自其他文章。  2024/01/04  欧阳康
# 18                                                NaN  2024/01/04  陈晓雅
# 19                                GSE137864,GSE149938  2024/01/04  陈晓雅
# 20                      GSE94820,raw数据在左边链接中，需向作者申请权限  2024/01/04  陈晓雅
# 21                                                NaN  2024/01/04  陈晓雅
# 22  Raw UMI counts and normalized expression value...  2024/01/04  陈晓雅
# 23                                        syn22255433  2024/01/04  陈晓雅
# 25                                                NaN  2024/01/04  陈晓雅
# 27                                                NaN  2024/01/04  陈晓雅
# 28                                          GSE213516  2024/01/04  陈晓雅
# 31                              EGA: S00001004412检索不到  2024/01/04  陈晓雅
# 32                                                需申请  2024/01/04  陈晓雅
# 33                                          GSE106544  2024/01/04  陈晓雅
# 35                      这篇文章所提供的序列号是错误的，数据可能得发邮件向作者索取  2024/01/04  陈晓雅
#
#     文章信息状态 数据状态
# 2      待检查  待收集
# 3      待检查  待收集
# 6      待检查  待收集
# 7      待检查  待收集
# 13     待检查  待收集
# 14     待检查  待收集
# 15     待检查  待收集
# 16     待检查  待收集
# 18     待检查  待收集
# 19     待检查  待收集
# 20     待检查  待收集
# 21     待检查  待收集
# 22     待检查  待收集
# 23     待检查  待收集
# 25     待检查  待收集
# 27     待检查  待收集
# 28     待检查  待收集
# 31     待检查  待收集
# 32     待检查  待收集
# 33     待检查  待收集
# 35     待检查  待收集
#
# [21 rows x 37 columns]
