# %%
import pandas as pd

data = pd.read_csv('/home/ouconstand/data/Virus_Host/non_homo_host_info.csv')

# %%
data.head()
# Out:
#    VirusTaxID  HostTaxID Representation  Length HostGenus HostFamily  \
# 0      694014       8835     AJ311317.1   27635      anas   anatidae
# 1      694014       8835     MT984601.1   27779      anas   anatidae
# 2      694014       8835     MK581207.1   27791      anas   anatidae
# 3      694014       8835     MK581202.1   27875      anas   anatidae
# 4      694014       8835     MN517817.1   27944      anas   anatidae
#
#       HostOrder HostClass
# 0  anseriformes      aves
# 1  anseriformes      aves
# 2  anseriformes      aves
# 3  anseriformes      aves
# 4  anseriformes      aves

# %%
genus_data = pd.DataFrame(data.HostGenus.value_counts())
genus_data = genus_data.reset_index()
genus_data.columns = ['Genus', 'Count']
genus_data.hist(orientation='horizontal')
# Out:
# array([[<AxesSubplot:title={'center':'Count'}>]], dtype=object)

# %%
genus_data[genus_data['Count'] < 2]
# Out:
#                Genus  Count
# 99       chlamydotis      1
# 100           sterna      1
# 101         pitangus      1
# 102    falsistrellus      1
# 103            falco      1
# 104        megascops      1
# 105        leopardus      1
# 106             puma      1
# 107     mesocricetus      1
# 108          amazona      1
# 109         melogale      1
# 110         meriones      1
# 111         penelope      1
# 112      aptenodytes      1
# 113           agamia      1
# 114         tursiops      1
# 115     afronycteris      1
# 116     gerbilliscus      1
# 117   delphinapterus      1
# 118        gallinula      1
# 119       spheniscus      1
# 120        porphyrio      1
# 121  orientallactaga      1
# 122            sorex      1
# 123         rupornis      1
# 124        scotoecus      1
# 125        pyroderus      1
# 126       ailuropoda      1
# 127           aythya      1
# 128         acerodon      1
# 129       nycticebus      1
# 130           fulica      1
# ...

# %%
family_data = pd.DataFrame(data.HostFamily.value_counts())
family_data = family_data.reset_index()
family_data.columns = ['HostFamily', 'Count']
family_data
# Out:
#           HostFamily  Count
# 0   vespertilionidae    289
# 1      rhinolophidae    225
# 2        phasianidae    184
# 3       pteropodidae    148
# 4            muridae    116
# ..               ...    ...
# 58    rhinopomatidae      1
# 59       tayassuidae      1
# 60          cracidae      1
# 61      heteromyidae      1
# 62        giraffidae      1
#
# [63 rows x 2 columns]

# %%
family_data[family_data['Count'] < 2]
# Out:
#         HostFamily  Count
# 47         ursidae      1
# 48      tyrannidae      1
# 49       dipodidae      1
# 50    monodontidae      1
# 51     delphinidae      1
# 52       lorisidae      1
# 53     psittacidae      1
# 54  haematopodidae      1
# 55        otididae      1
# 56      cotingidae      1
# 57    accipitridae      1
# 58  rhinopomatidae      1
# 59     tayassuidae      1
# 60        cracidae      1
# 61    heteromyidae      1
# 62      giraffidae      1

# %%
order_data = pd.DataFrame(data.HostOrder.value_counts())
order_data = order_data.reset_index()
order_data.columns = ['Order', 'Count']
order_data
# Out:
#               Order  Count
# 0        chiroptera    772
# 1       galliformes    185
# 2         carnivora    144
# 3          rodentia    141
# 4      artiodactyla     78
# 5      anseriformes     59
# 6   charadriiformes     28
# 7     passeriformes     19
# 8        lagomorpha     18
# 9      eulipotyphla     17
# 10   perissodactyla      7
# 11         primates      7
# 12   pelecaniformes      5
# 13     strigiformes      4
# 14       gruiformes      4
# 15        pholidota      4
# 16    columbiformes      3
# 17    falconiformes      3
# 18  accipitriformes      3
# 19       piciformes      2
# 20  sphenisciformes      2
# 21   psittaciformes      1

# %%
class_data = pd.DataFrame(data.HostClass.value_counts())
class_data = class_data.reset_index()
class_data.columns = ['Class', 'Count']
class_data
# Out:
#       Class  Count
# 0  mammalia   1188
# 1      aves    318
