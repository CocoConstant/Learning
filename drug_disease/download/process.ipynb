# %%
import pandas as pd

drug_diseases_data = pd.read_csv("/home/ouconstand/data/Drug_Disease/CTD_chemicals_diseases.csv", comment="#")

display(drug_diseases_data.head(10))
# Out:
#               ChemicalName ChemicalID CasRN  \
# 0  06-Paris-LA-66 protocol    C046983   NaN
# 1                 10074-G5    C534883   NaN
# 2                 10074-G5    C534883   NaN
# 3                 10074-G5    C534883   NaN
# 4                 10074-G5    C534883   NaN
# 5                 10074-G5    C534883   NaN
# 6                 10074-G5    C534883   NaN
# 7                 10074-G5    C534883   NaN
# 8                 10074-G5    C534883   NaN
# 9                 10074-G5    C534883   NaN
#
#                                       DiseaseName        DiseaseID  \
# 0  Precursor Cell Lymphoblastic Leukemia-Lymphoma     MESH:D054198
# 1                                  Adenocarcinoma     MESH:D000230
# 2                          Adenocarcinoma of Lung  MESH:D000077192
# 3                                        Alopecia     MESH:D000505
# 4                 Androgen-Insensitivity Syndrome     MESH:D013734
# 5                                     Astrocytoma     MESH:D001254
# ...

# %%
drug_diseases_data.shape
# Out:
# (8146415, 10)

# %%
therapeutic = drug_diseases_data[drug_diseases_data["DirectEvidence"] == 'therapeutic']

# %%
therapeutic.head()
# Out:
#                                            ChemicalName ChemicalID  \
# 0                               06-Paris-LA-66 protocol    C046983
# 162               10,11-dihydro-10-hydroxycarbamazepine    C039775
# 1101                             10-hydroxycamptothecin    C028098
# 1113                             10-hydroxycamptothecin    C028098
# 1364  10-methoxy-2,2-dimethyl-2,6-dihydropyrano(3,2-...    C554291
#
#            CasRN                                     DiseaseName  \
# 0            NaN  Precursor Cell Lymphoblastic Leukemia-Lymphoma
# 162          NaN                                        Epilepsy
# 1101  67656-30-8                              Huntington Disease
# 1113  67656-30-8                                 Liver Neoplasms
# 1364         NaN                                        Leukemia
#
#          DiseaseID DirectEvidence InferenceGeneSymbol  InferenceScore OmimIDs  \
# 0     MESH:D054198    therapeutic                 NaN             NaN     NaN
# ...

# %%
therapeutic = therapeutic[["ChemicalName", "ChemicalID", "DiseaseName", "DiseaseID"]]

# %%
therapeutic.to_csv("therapeutic_drug_diseases.csv", header=True, index=None)
