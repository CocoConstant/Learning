# %%
import pandas as pd

# %%
data = pd.read_csv('/mnt/c/Users/ouyangkang/Desktop/result_escc_250109.csv')
data.head()
# Out:
#                 SampleID                                              cDNA1  \
# 0  ESCC_PBMC_2411093_M-1  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 1  ESCC_PBMC_2411093_M-2  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 2  ESCC_PBMC_2416288_M-1  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 3  ESCC_PBMC_2416288_M-2  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 4  ESCC_PBMC_2419509_P-1  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
#
#                                                cDNA2  \
# 0  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 1  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 2  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 3  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
# 4  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T10/P24Z31300N0...
#
#                                               Oligo1  \
# 0  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...
# 1  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...
# 2  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...
# 3  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...
# 4  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...
#
#                                               Oligo2  genomeDir Outdir  \
# 0  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...        NaN     ./
# 1  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...        NaN     ./
# 2  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...        NaN     ./
# 3  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...        NaN     ./
# 4  /zfsqd2/zebra07/QD_DIPSEQ_DATA/T1/P24Z31300N00...        NaN     ./
#
#    expectcells  forcecells  Cpu  Mem
# 0         5000           0    8   80
# 1         5000           0    8   80
# 2         5000           0    8   80
# 3         5000           0    8   80
# 4         5000           0    8   80

# %%
data['cDNA1'] = '/Files/RawData/' + data['cDNA1'].str.split('/').str[-1]
data['cDNA2'] = '/Files/RawData/' + data['cDNA2'].str.split('/').str[-1]

data['Oligo1'] = '/Files/RawData/' + data['Oligo1'].str.split('/').str[-1]
data['Oligo2'] = '/Files/RawData/' + data['Oligo2'].str.split('/').str[-1]

# %%
data.to_csv('/mnt/c/Users/ouyangkang/Desktop/result_250109_escc_UpCloud.csv', index=None)
