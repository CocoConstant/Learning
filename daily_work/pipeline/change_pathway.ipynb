# %%
import pandas as pd

# %%
data = pd.read_csv('/mnt/c/Users/ouyangkang/Downloads/result_0423.csv')
data.head()
# Out:
#                  Sample                                             Oligo1  \
# 0      SYM_P_2411093-17  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 1  PBMC_ZAP_P_2430072-8  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 2  PBMC_YGL_S_2428374-4  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 3      SYM_P_2411093-18  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 4  PBMC_ZAP_S_2430072-6  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
#
#                                               Oligo2  \
# 0  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 1  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 2  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 3  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 4  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
#
#                                                cDNA1  \
# 0  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 1  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 2  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 3  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
# 4  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...
#
#                                                cDNA2  genomeDir Outdir  \
# 0  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...        NaN     ./
# 1  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...        NaN     ./
# 2  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...        NaN     ./
# 3  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...        NaN     ./
# 4  /jdfsms2/CNGB_DATA/BGISEQ01/DIPSEQ/DIPSEQT20/P...        NaN     ./
#
#    expectcells  forcecells  Cpu  Mem
# 0        10000       False    8  120
# 1        10000       False    8  120
# 2        10000       False    8  120
# 3        10000       False    8  120
# 4        10000       False    8  120

# %%
data['cDNA1'] = '/Files/RawData/' + data['cDNA1'].str.split('/').str[-1]
data['cDNA2'] = '/Files/RawData/' + data['cDNA2'].str.split('/').str[-1]

data['Oligo1'] = '/Files/RawData/' + data['Oligo1'].str.split('/').str[-1]
data['Oligo2'] = '/Files/RawData/' + data['Oligo2'].str.split('/').str[-1]

# %%
data.to_csv('/mnt/c/Users/ouyangkang/Desktop/result_250401_escc_UpCloud.csv', index=None)
