# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# %%
educated_module = ['SKAP1', 'PTPN13', 'TAFA1', 'AC093865.1', 'RORA', 'TSHZ2', 'LINGO2', 'PRKCH', 'INPP4B', 'CAMK4', 'CD247', 'FYN', 'KLF12', 'AL589693.1', 'IKZF2', 'NCALD', 'LEF1', 'TOX', 'TGFBR3', 'ANK3', 'LRBA', 'CNTNAP1', 'CXXC5', 'NR3C2', 'LINC00298', 'BACH2', 'MVK', 'AL136456.1', 'IL7R', 'SLC16A10', 'SAMD3', 'PRKCA', 'DOCK10', 'FAAH2', 'NELL2', 'ETS1', 'EDA', 'PPP2R2B', 'BCL11B', 'NCAM1', 'SLFN12L', 'BCL2', 'LINC01934', 'LINC00861', 'TXK', 'STAT4', 'AK5', 'TTN', 'CBLB', 'CD96', 'BNC2', 'AMDHD1', 'IMMP2L', 'LINC00824', 'MLLT3', 'ZC2HC1A', 'TNIK', 'MDFIC', 'RASGRP1', 'OSBPL3', 'SYNE1', 'FARS2', 'C1orf21', 'ITK', 'CD226', 'CHODL', 'HIVEP3', 'PPM1L', 'WWOX', 'PVT1', 'SGCD', 'AC002460.2', 'SATB1-AS1', 'FAT4', 'ZMAT4', 'ATF7IP2', 'AL356020.1', 'AF165147.1', 'STK39', 'MYBL1', 'SMAD3', 'OXNAD1', 'ZBTB16', 'CMSS1', 'FUT8', 'PYHIN1', 'TCF7', 'COLQ', 'GZMB', 'MTSS1', 'GRAP2', 'ZNF831', 'AL359232.1', 'ARHGEF3', 'ANTXRLP1', 'ASCC3', 'RHOH', 'TCF12', 'MAN1C1', 'ARID5B', 'PHACTR2', 'TRAC', 'LEF1-AS1', 'CAMK2D', 'TESPA1', 'AC139720.1', 'ST8SIA1', 'PIK3R3', 'LINC00426', 'SNORD3A', 'PRKACB', 'CACNA2D2', 'RDH5', 'AL035701.1', 'LRRN3', 'C15orf53', 'AHNAK', 'SLC16A7', 'MAP2K5', 'KCNQ5', 'FTO', 'NFATC2', 'SLC4A7', 'PRKCQ', 'RFTN1', 'CLEC2D', 'CHRM3-AS2', 'LINC00402', 'SLFN5', 'PCAT1', 'PCED1B', 'VGLL4', 'PDGFD', 'DPP4', 'TC2N', 'MAGED1', 'ANKRD36', 'TTC39C', 'NUBPL', 'TSPAN5', 'RPL37A', 'AL353660.1', 'RNF157', 'MBNL2', 'RCAN3', 'TMEM156', 'CD6', 'KLRF1', 'UPP2', 'LINC00944', 'MSC-AS1', 'SUPT3H', 'RAB27B', 'AC015911.8', 'LINC01278', 'TIAM1', 'GPRIN3', 'SYTL2', 'LINC01473', 'PLEKHA5', 'RAB30', 'CCNF', 'DCAF17', 'CEP78', 'PCCA', 'PRKCQ-AS1', 'PCF11-AS1', 'EPHA4', 'MFSD6', 'SUCLG2', 'LINC00649', 'EVL', 'NOTCH3', 'TTC39B', 'JAKMIP2', 'PTCH1', 'TMEM182', 'ATXN7L1', 'RASGRF2', 'DIPK1A', 'RGS5', 'COX10-AS1', 'EDNRB-AS1', 'MCUB', 'UST', 'LBH', 'AL365475.1', 'DLEU1', 'IGFBP7', 'OGFOD3', 'AGPAT4-IT1', 'KDM4C', 'POP1', 'SLC38A1', 'CCDC88C', 'CDKAL1', 'ST6GAL1', 'PCNX2', 'ZNF419', 'ZNF786', 'CD28', 'SCFD2', 'CD244', 'AC137810.1', 'ZMYND11', 'TRG-AS1', 'GPHN', 'PLCXD2', 'VPS13A', 'SLC10A7', 'C4orf50', 'AL133467.2', 'PTGDR', 'SPATA5', 'CCDC91', 'RPS8', 'DIRC3', 'IKZF3', 'ITGB1', 'AL359715.3', 'SCMH1', 'PKIA-AS1', 'RPLP2', 'TMEM135', 'CHD6', 'TMEM161B-AS1', 'URI1', 'RPAP2', 'CUL4A', 'AC078929.1', 'NMT2', 'EZH2', 'TADA1', 'PCYT2', 'SFMBT2', 'TDRD3', 'PTPN4', 'JAM3', 'TRGC1', 'SETBP1', 'TRPT1', 'LGR6', 'AC093423.2', 'ERVMER61-1', 'THUMPD2', 'PRSS23', 'DGKH', 'NDUFAF2', 'LINC01184', 'SLC14A1', 'VWA8', 'YES1', 'PHF14', 'PPP3CC', 'AUTS2', 'AC092634.3', 'TUBGCP4', 'METAP2', 'CEP128', 'SNHG14', 'GSPT2', 'ACVR2A', 'CLYBL', 'TRABD2A', 'DTHD1', 'MYO3B', 'ANKH', 'KLRG1', 'TRGC2', 'PLEKHA1', 'ATP10A', 'PKIA', 'S1PR5', 'CCDC14', 'FAM83D', 'USP9Y', 'AC118549.1', 'S1PR1', 'AC005921.3', 'FHIT', 'CENPK', 'KLRC4-KLRK1', 'KIF2A', 'DIS3L2', 'FSD1L', 'CD3E', 'COMMD10', 'TTC19', 'CARD11', 'SIDT1', 'AL049697.1', 'PPP1R16B', 'ARHGAP5', 'TLE5', 'RPTOR', 'OPTN', 'PITPNC1', 'SNORD53', 'ZFYVE28', 'AF127577.4', 'NAF1', 'GOLM1', 'TBCK', 'LRPPRC', 'AC002377.1', 'KLRA1P', 'UBASH3A', 'F2R', 'PARP15', 'ZNF300', 'MAN1A2', 'IQCH', 'AEN', 'CWC27', 'COX10', 'FAM102A', 'ARHGAP10']
module_1 = ['MNDA', 'TMSB4X', 'MT-CO3', 'S100A8', 'OAZ1', 'MYL6', 'HLA-E', 'ATP5F1E', 'PSAP', 'FTH1', 'B2M', 'HLA-B', 'H3F3A', 'LYZ', 'S100A9', 'ACTB', 'TMSB10', 'RPL7', 'S100A4', 'RPL13', 'TPT1', 'EEF1A1', 'RPLP2', 'RPS12', 'RPS24', 'RPL23', 'RPL11', 'RPL32', 'S100A6', 'RPL9', 'RPS11', 'SERPINA1', 'PTMA', 'UBA52', 'PFDN5', 'RPS27', 'RPL34', 'CTSS', 'RPS8', 'FTL', 'RPL37', 'NACA', 'TYMP', 'LAPTM5', 'LST1', 'FCN1', 'RPL27A', 'COTL1', 'VCAN', 'RPS9', 'AP006565.1', 'RPS10', 'KLF2', 'RPL28', 'TXNIP', 'MT-CO2', 'SAMHD1', 'RPL13A', 'PFN1', 'RPS17', 'HLA-DRA', 'RPL4', 'RPS28', 'RPS3A', 'MT-ND4', 'RPL36A', 'VIM', 'RPL37A', 'GABARAP', 'ACTG1', 'TPM3', 'EIF4A1', 'SLC27A4', 'RPL39', 'TKT', 'FGL2', 'RPS27A', 'RPL30', 'CTSD', 'HLA-A', 'TSPO', 'RPL26', 'MT-ATP6', 'PABPC1', 'DAZAP2', 'RAB24', 'ITGB2', 'RPL29', 'ATP6V0C', 'RPL3', 'RPL36', 'BTG1', 'RPL8', 'EVI2B', 'RPL21', 'PCBP2', 'HNRNPA1', 'SLC11A1', 'SH3BGRL3', 'SERF2', 'RPS4X', 'COX4I1', 'RPS29', 'CD93', 'GRN', 'TYROBP', 'RPS25', 'RPS14', 'AHNAK', 'RPS6', 'HNRNPA2B1', 'EIF3L', 'ARPC1B', 'RPL35', 'RPL12', 'ARHGDIB', 'ZFP36L2', 'RPL5', 'UQCRB']
module_2 = ['CSF3R', 'NEAT1', 'RIPOR2', 'RNF149', 'MYO1F', 'SRGN', 'VMP1', 'LITAF', 'LUCAT1', 'SLC25A37', 'TNFRSF10C', 'LYN', 'SSH2', 'KCNJ15', 'AQP9', 'SMCHD1', 'RBM47', 'ARHGAP15', 'BASP1', 'CAMK1D', 'SORL1', 'PICALM', 'NUMB', 'NIBAN1', 'PIK3CD', 'USP15', 'RNF24', 'CPPED1', 'MXD1', 'XPO6', 'ACSL1', 'ARHGAP26', 'NCOA1', 'ADAMTSL4-AS1', 'APBB1IP', 'RESF1', 'GAB2', 'LIMK2', 'PELI1', 'ANKRD44', 'CFLAR', 'AC099489.1', 'ZFAND3', 'COP1', 'ST8SIA4', 'EPHB1', 'FAM126B', 'FFAR2', 'ELF2', 'BAZ1A', 'PTEN', 'USP32', 'HCK', 'FPR2', 'MEGF9', 'EPB41', 'CHST15', 'GLT1D1', 'ADGRE3', 'TECPR2', 'MED13L', 'MCTP2', 'TMCC1', 'SRPK2', 'UBR2', 'FAM49B', 'ARID4B', 'ACAP2', 'DOCK5', 'RPS6KA5', 'AC016831.7', 'PARP8', 'STAT3', 'TNRC6B', 'RICTOR', 'ENTPD1', 'PACS1', 'ASAP1', 'BCL2A1', 'PTPRJ', 'AL078604.4', 'MBP', 'CPQ', 'NCOA2', 'PCNX1', 'PAN3', 'RGL4', 'FAM13B', 'NFAT5', 'CEACAM3', 'UBE2R2']
module_3 = ['INTS14', 'TEX35', 'OBSL1', 'CCL14', 'AL357141.1', 'AL136298.1', 'GIP', 'LINC00615', 'LINC00508', 'PITX3', 'H3F3C', 'BX276092.9', 'HSCB', 'GMNN', 'AP002754.1', 'AL031123.1', 'NT5C1A', 'MYL3', 'AC087477.4', 'AC008459.1', 'XIAP', 'ARSE', 'TBC1D7', 'MSC', 'AC090505.2', 'LINC02316', 'UBIAD1', 'BARD1', 'NAF1', 'SMPDL3A', 'MEIS1', 'AC000061.1', 'AC098588.3', 'AL138773.1', 'ANKS6', 'AL391097.2', 'PDE5A', 'SP100', 'AC019131.1', 'TDRD5', 'AL353681.1', 'CCDC198', 'LINC01416', 'CCER1', 'MUC13', 'AC004594.1', 'TTC8', 'PARVB', 'PRX', 'LINC02154', 'GSTA3', 'WDPCP', 'LINC01563', 'AC012433.2', 'AC099541.2', 'CYP1A2', 'CYP4A22', 'SIRT5', 'PCSK2', 'APOBEC3H', 'ZGPAT', 'LINC01467', 'ZNF691', 'AL160408.6', 'MYSM1']

# %%
setA = set(educated_module)
setB = set(module_1)
setC = set(module_2)
setD = set(module_3)

# %%
plt.figure(figsize=(10, 10))
venn3([setA, setB, setC], ('A', 'B', 'C'))
plt.title("Venn Diagram: A, B, C")
plt.show()

# 绘制以B为参考的三组集合交集
plt.figure(figsize=(10, 10))
venn3([setB, setC, setD], ('B', 'C', 'D'))
plt.title("Venn Diagram: B, C, D")
plt.show()

# 绘制以C为参考的三组集合交集
plt.figure(figsize=(10, 10))
venn3([setC, setD, setA], ('C', 'D', 'A'))
plt.title("Venn Diagram: C, D, A")
plt.show()

# 绘制以D为参考的三组集合交集
plt.figure(figsize=(10, 10))
venn3([setD, setA, setB], ('D', 'A', 'B'))
plt.title("Venn Diagram: D, A, B")
plt.show()

# %%
type(module_1)
# Out:
# list
