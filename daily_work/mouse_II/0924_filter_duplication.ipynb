# %%
import pandas as pd

# %%
data = pd.read_excel("/mnt/c/Users/ouyangkang/Downloads/P23Z10200N0911.xlsx")
# Out:
# /home/ouyangkang/software/miniconda3/envs/sc/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
data.drop_duplicates(["Task ID"], inplace=True)

# %%
data.drop_duplicates(["Entity ID"])
# Out:
#          Project ID           Task ID  SN        Entity ID  \
# 0    P23Z10200N0911  W202409180004846 NaN  V2.5R2406190069
# 12   P23Z10200N0911  W202409180004845 NaN  V2.5R2406190067
# 22   P23Z10200N0911  W202409180004844 NaN  V2.5R2406190068
# 34   P23Z10200N0911  W202409180004843 NaN  V2.5R2407050037
# 46   P23Z10200N0911  W202409180004842 NaN  V2.5R2407050058
# 58   P23Z10200N0911  W202409180004841 NaN  V2.5R2407050039
# 70   P23Z10200N0911  W202409180004840 NaN  V2.5R2407050038
# 82   P23Z10200N0911  W202409180004839 NaN  V2.5R2407050044
# 94   P23Z10200N0911  W202409180004838 NaN  V2.5R2407050043
# 106  P23Z10200N0911  W202409180004837 NaN  V2.5R2407050046
# 118  P23Z10200N0911  W202409180004836 NaN  V2.5R2407050045
# 130  P23Z10200N0911  W202409180004835 NaN  V2.5R2407050040
# 142  P23Z10200N0911  W202409180004834 NaN  V2.5R2407050042
# 154  P23Z10200N0911  W202409180004833 NaN  V2.5R2407050041
# 164  P23Z10200N0911  W202409180004832 NaN  V2.5R2406190076
# ...
