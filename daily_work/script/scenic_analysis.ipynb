# %% [markdown]
# __Date:__ 3 Aug 2023

# %%
import os
import pandas as pd
from pyscenic.export import export2loom
from pyscenic.utils import load_motifs
from pyscenic.transform import df2regulons
import scanpy as sc

# %%
sc_data = sc.read_h5ad('/mnt/c/Users/ouyangkang/Desktop/convert_sc_data.h5ad')

# %%
sc_data
# Out:
# AnnData object with n_obs × n_vars = 238242 × 16725
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'cell', 'pANN', 'library', 'RNA_snn_res.0.5', 'seurat_clusters', 'collected_time', 'infer_age', 'infer_age_int', 'tissue_old', 'sub_cluster_number', 'celltype', 'tissue_update', 'germ_layer', 'subtype'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_harmony', 'X_pca', 'X_scvi', 'X_umap'

# %%
import anndata

# %%
extract_data = anndata.read_h5ad('/mnt/c/Users/ouyangkang/Desktop/convert_sc_data.h5ad')

# %%
extract_data
# Out:
# AnnData object with n_obs × n_vars = 238242 × 16725
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'percent.mt', 'cell', 'pANN', 'library', 'RNA_snn_res.0.5', 'seurat_clusters', 'collected_time', 'infer_age', 'infer_age_int', 'tissue_old', 'sub_cluster_number', 'celltype', 'tissue_update', 'germ_layer', 'subtype'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_harmony', 'X_pca', 'X_scvi', 'X_umap'

# %%
import pandas as pd

cell_gene_matrix = pd.DataFrame(extract_data.X, columns=extract_data.obs.index.tolist(), index=)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
extract_data.X
# Out:
# <238242x16725 sparse matrix of type '<class 'numpy.float32'>'
# 	with 472539235 stored elements in Compressed Sparse Column format>

# %%
extract_data.var.index.tolist()
# Out:
# ['CR11023',
#  'l(2)gl',
#  'Cda5',
#  'CG3625',
#  'CG3164',
#  'Ets21C',
#  'ND-15',
#  'galectin',
#  'spen',
#  'Sam-S',
#  'CG3645',
#  'CG4822',
#  'Gs1',
#  'Plc21C',
#  'kis',
#  'Ir21a',
#  'asRNA:CR43609',
#  'CG11377',
#  'CG4133',
#  'mbm',
#  'dbr',
#  'U2af38',
#  'RpLP1',
#  'CG3436',
#  'CG11601',
#  'Zir',
#  'Tbc1d15-17',
#  'lncRNA:CR46254',
#  'asRNA:CR44969',
#  'MED15',
#  'lncRNA:CR43717',
#  'Nhe1',
#  'asRNA:CR44987',
#  'CG31974',
#  'CG13694',
#  'CG42399',
#  'ovm',
#  'Spp',
#  'lncRNA:CR45339',
#  'CG11374',
#  'Pi3K21B',
#  'lwr',
#  'CG11555',
#  'net',
#  'Rpp30',
#  'mRpL10',
#  'CG17075',
#  'CG33127',
#  'crq',
#  'lncRNA:CR44185',
#  'lncRNA:CR44186',
#  'Ent1',
#  'CG13689',
#  'CG11562',
#  'CG11454',
#  'Stip1',
#  'CG33635',
#  'CG3709',
#  'smo',
#  'CG4213',
#  'CG13690',
#  'Amnionless',
#  'CG17078',
#  'Eaat2',
#  'CG4297',
#  'CG11885',
#  'AP-2alpha',
#  'CG11617',
#  'cbt',
#  'cold',
#  'lncRNA:CR44220',
#  'lncRNA:CR44222',
#  'ds',
# ...

# %%
extract_data.X
# Out:
# <238242x16725 sparse matrix of type '<class 'numpy.float32'>'
# 	with 472539235 stored elements in Compressed Sparse Column format>

# %%
extract_data.obs.cell
# Out:
# index
# CELL344_N2_1_1    CELL344_N2_1_1
# CELL345_N1_1_1    CELL345_N1_1_1
# CELL346_N3_1_1    CELL346_N3_1_1
# CELL347_N2_1_1    CELL347_N2_1_1
# CELL348_N1_1_1    CELL348_N1_1_1
#                        ...
# CELL8956_N1_6      CELL8956_N1_6
# CELL8959_N1_6      CELL8959_N1_6
# CELL8963_N1_6      CELL8963_N1_6
# CELL8982_N1_6      CELL8982_N1_6
# CELL9001_N1_6      CELL9001_N1_6
# Name: cell, Length: 238242, dtype: object

# %%
extract_data.var.index
# Out:
# Index(['CR11023', 'l(2)gl', 'Cda5', 'CG3625', 'CG3164', 'Ets21C', 'ND-15',
#        'galectin', 'spen', 'Sam-S',
#        ...
#        'lncRNA:CR45394', 'mir-2500', 'snoRNA:Or-CD10', 'mir-13b-2',
#        'lncRNA:CR43491', 'tRNA:Lys-TTT-1-1', 'CR43483', 'tRNA:Arg-TCG-2-3',
#        'CG34312', 'snoRNA:Or-CD11c'],
#       dtype='object', name='index', length=16725)
