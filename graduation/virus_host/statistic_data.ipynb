# %%
import pandas as pd

with open('/home/bio_kang/virus_host_virion/Virion.csv','rb') as f:
    lines = f.readlines()

data_procession = []
for line in lines:
    if len(line) < 34:
        continue
    else:
        data = line.decode('ISO-8859-1').strip('\n').split('\t')

        if data[3] == '' or data[4] == "FALSE" or data[4] == '':
            continue
        else:
            data_procession.append(data)



data = pd.DataFrame(data_procession[1:-1],columns=data_procession[0])

# %%
data
# Out:
#                          Host                    Virus HostTaxID VirusTaxID  \
# 0                                                          10046      10892
# 1                                                          10046      11572
# 2                                                          10046      11584
# 3                                                          10046    1980517
# 4                                                          10046      35323
# ...                       ...                      ...       ...        ...
# 483050  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 483051  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 483052  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 483053  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 483054  zygodontomys cherriei   rio segundo hantavirus    218840      37207
#
#        HostNCBIResolved VirusNCBIResolved ICTVRatified     HostGenus  \
# 0                  TRUE              TRUE        FALSE      meriones
# 1                  TRUE              TRUE        FALSE      meriones
# 2                  TRUE              TRUE        FALSE      meriones
# 3                  TRUE              TRUE        FALSE      meriones
# 4                  TRUE              TRUE        FALSE      meriones
# ...                 ...               ...          ...           ...
# 483050             TRUE              TRUE         TRUE  zygodontomys
# 483051             TRUE              TRUE         TRUE  zygodontomys
# 483052             TRUE              TRUE         TRUE  zygodontomys
# 483053             TRUE              TRUE         TRUE  zygodontomys
# 483054             TRUE              TRUE        FALSE  zygodontomys
#
#         HostFamily HostOrder  ... PMID ReleaseYear ReleaseMonth ReleaseDay  \
# 0          muridae  rodentia  ...
# 1          muridae  rodentia  ...
# 2          muridae  rodentia  ...
# 3          muridae  rodentia  ...
# 4          muridae  rodentia  ...
# ...            ...       ...  ...  ...         ...          ...        ...
# 483050  cricetidae  rodentia  ...             2012            2         15
# 483051  cricetidae  rodentia  ...             2015            8         29
# 483052  cricetidae  rodentia  ...             2015            8         29
# 483053  cricetidae  rodentia  ...
# 483054  cricetidae  rodentia  ...
#
#        CollectionYear CollectionMonth CollectionDay AssocID DatabaseDOI  \
# 0
# 1
# 2
# 3
# 4
# ...               ...             ...           ...     ...         ...
# 483050           2008
# 483051           2008               3            16
# 483052           2010               7            31
# 483053
# 483054
#
#                  NCBIAccession
# 0
# 1
# 2
# 3
# 4
# ...                        ...
# 483050  JN717148.1, JN717149.1
# 483051              KM196124.1
# 483052              KM196123.1
# 483053
# 483054
#
# [483055 rows x 34 columns]

# %%
data['']
