# %% [markdown]
# # 1 data screen

# %% [markdown]
# ## 1.1 easily screen
#     condition:
#         1. must concluding virus, host, hostTaxID and VirusTaxID

# %%
import pandas as pd

with open('/home/ouyangkang/virus_host/Virion.csv','rb') as f:
    lines = f.readlines()

data_procession = []
for line in lines:
    if len(line) < 34:
        continue
    else:
        data = line.decode('ISO-8859-1').strip('\n').split('\t')

        if data[0] == '' or data[1]=='' or data[2]=='' or data[3] == '' :
            continue
        else:
            data_procession.append(data)



data = pd.DataFrame(data_procession[1:-1],columns=data_procession[0])

# %%
data
# Out:
#                          Host                    Virus HostTaxID VirusTaxID  \
# 0               abramis brama         bream circovirus     38527    1494919
# 1               abramis brama         carp sprivivirus     38527     696863
# 2               abramis brama         carp sprivivirus     38527     696863
# 3               abramis brama         carp sprivivirus     38527     696863
# 4               abramis brama         carp sprivivirus     38527     696863
# ...                       ...                      ...       ...        ...
# 469941  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 469942  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 469943  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 469944  zygodontomys cherriei  necocli orthohantavirus    218840    1980482
# 469945  zygodontomys cherriei   rio segundo hantavirus    218840      37207
#
# ...

# %%
data.shape
# Out:
# (469946, 34)

# %%
# delete na in row of NCBIaccession
accession_data = data.dropna(subset=['NCBIAccession'], axis=0)

# delete null in row of NCBIaccession
no_null_accession = data[data["NCBIAccession"] != ""]

# %%
no_null_accession.shape
# Out:
# (418016, 34)

# %%
display(no_null_accession)
# Out:
#                            Host                      Virus HostTaxID  \
# 0                 abramis brama           bream circovirus     38527
# 3                 abramis brama           carp sprivivirus     38527
# 5                 abramis brama           carp sprivivirus     38527
# 12                abramis brama  pike fry-like rhabdovirus     38527
# 13         abrothrix longipilis      andes orthohantavirus     29094
# ...                         ...                        ...       ...
# 469925  zygodontomys brevicauda    necocli orthohantavirus    157541
# 469930  zygodontomys brevicauda     pirital mammarenavirus    157541
# 469941    zygodontomys cherriei    necocli orthohantavirus    218840
# 469942    zygodontomys cherriei    necocli orthohantavirus    218840
# 469943    zygodontomys cherriei    necocli orthohantavirus    218840
#
#        VirusTaxID HostNCBIResolved VirusNCBIResolved ICTVRatified  \
# 0         1494919             TRUE              TRUE        FALSE
# ...

# %% [markdown]
# ## 2.1 reserve simply process data

# %%
no_null_accession.to_csv('/home/ouyangkang/virus_host/process_Virion.csv', index=None, header=True)

# %% [markdown]
# ## abnormal condition

# %%
data_from = data.drop_duplicates(["VirusTaxID","HostTaxID"])
data_from.shape
# Out:
# (21081, 34)

# %%
no_null_acc = data_from[data_from["NCBIAccession"] != ""]
no_null_acc.shape
# Out:
# (8093, 34)

# %% [markdown]
# # 3 draw graph

# %%
data_from = data_from["Database"].value_counts()

# %%
import matplotlib.pyplot as plt

plt.figure(dpi=300,figsize=(24,8))
plt.pie(data_from, explode=(0,0,0,0,0.1,0.2,0.3), autopct='%3.2f%%', pctdistance=1.1)
plt.legend(labels=data_from.index, loc="right", bbox_to_anchor=(1,1))
plt.savefig("database_statistic.png", format='png', bbox_inches='tight', dpi=300, transparent=True)
