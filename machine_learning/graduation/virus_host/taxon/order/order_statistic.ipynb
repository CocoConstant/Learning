# %%
import pandas as pd

passed_data = []
data_procession = []
with open('/home/ouconstand/data/Virus_Host/Virion.csv','r', encoding='ISO-8859-1') as f:
    for line in f.read().splitlines():
        data = line.split('\t')
        if len(data) < 34:
            passed_data.append(data)
        else:
            if data[7] == '' or data[2] == '' or data[3] == '': # delete non_family or non_virustaxid information data
                pass
            else:
                data_procession.append(data)

data = pd.DataFrame(data_procession[1:-1],columns=data_procession[0])

# %%
coro = data[data['VirusFamily'] == 'coronaviridae']

# %%
final_data = pd.DataFrame(columns=['HostOrder', 'Length_acce', 'Accession'])

n = 0
for hclass, vacce in coro.groupby(['HostOrder'])['NCBIAccession']:
    vacce = [acce.strip(' ') for acce in ','.join(list(vacce)).split(',') if acce != '']
    final_data.loc[n] = [hclass, len(vacce),vacce]
    n += 1

# %%
final_data
# Out:
#             HostOrder  Length_acce  \
# 0     accipitriformes           10
# 1        anseriformes          574
# 2        artiodactyla         7901
# 3           carnivora         3465
# 4     charadriiformes          135
# 5          chiroptera         5487
# 6       columbiformes           24
# 7       cypriniformes            1
# 8       diprotodontia            0
# 9        eulipotyphla          111
# 10      falconiformes            3
# 11        galliformes         8211
# 12         gruiformes            8
# 13         lagomorpha           47
# 14      passeriformes           35
# 15     pelecaniformes           75
# 16     perissodactyla           47
# 17          pholidota           17
# 18         piciformes            2
# 19           primates      1000307
# 20  procellariiformes            0
# 21     psittaciformes            5
# 22           rodentia          941
# 23    sphenisciformes            7
# 24           squamata            1
# 25       strigiformes           11
#
#                                             Accession
# 0   [KP256821.1, KP256822.1, KP256828.1, KP256832....
# 1   [AY702975.1, MF034362.1, MF034376.1, MF034359....
# 2   [KT368891.1, MF593476.1, KX897163.1, KT368895....
# 3   [38098849, 38098851, 38098853, AY436635.1, AY4...
# 4   [MG764134.1, MG764135.1, MG764136.1, MG764137....
# 5   [KF843853.1, HQ184060.1, LC334391.1, KM514667....
# 6   [KX588632.1, KX588636.1, 304359456, 304359458,...
# 7                                        [MW645029.1]
# 8                                                  []
# 9   [KX286017.1, KX286014.1, KX286014, KX285221.1,...
# 10               [LC364342.1, KP256841.1, KP256842.1]
# 11  [MK032181.1, MH924835.1, MK032177.1, MK032178....
# 12  [MK617400.1, LC364343.1, JQ065049.1, NC_016996...
# 13  [KM888175.1, KM888176.1, KM888174.1, KM888177....
# 14  [KU251476.1, KU251490.1, KU251477.1, 211907060...
# 15  [GU323504.1, 353444952, 353445000, 353445018, ...
# 16  [LC149485.1, LC149487.1, LC149489.1, MF318497....
# 17  [MT084071.1, MT040333.1, MT040334.1, MT040335....
# 18                           [KP256824.1, KP256837.1]
# 19  [AB548619.1, AB548620.1, AB548621.1, 285803947...
# 20                                                 []
# 21  [KP256820.1, KP211413.1, KP965434.1, KP965428....
# 22  [MT222079.1, LC334347.1, LC334348.1, LC334349....
# 23  [283510348, GU323505.1, MT025058.1, JX013533.1...
# 24                                       [MG600026.1]
# 25  [KP256827.1, KP256834.1, KP256838.1, KP256843....

# %%
final_data[['HostOrder','Length_acce']].to_csv('/mnt/c/Users/ouyangkang/Desktop/host_order_statistic.csv',index=None)
