# %%
import scanpy as sc
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ouyangkang/Learning/programing_language/Python/other_thing/01_agingfly_visualization.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ouyangkang/Learning/programing_language/Python/other_thing/01_agingfly_visualization.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import scanpy as sc
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/ouyangkang/Learning/programing_language/Python/other_thing/01_agingfly_visualization.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import numpy as np
#
# File ~/software/anaconda3/envs/scRNA/lib/python3.8/site-packages/scanpy/__init__.py:6
#       3 from ._metadata import __version__, within_flit
#       5 if not within_flit():  # see function docstring on why this is there
# ----> 6     from ._utils import check_versions
# ...

# %%
aging_data = sc.read_h5ad('/mnt/d/dailywork/aging_fly/adata_headBody_S_v1.0.h5ad')

# %%
aging_data
# Out:
# AnnData object with n_obs × n_vars = 566254 × 15992
#     obs: 'tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'dataset', 'fca_annotation', 'afca_annotation', 'afca_annotation_broad'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'age_colors', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'sex_colors', 'tissue_colors', 'tsne', 'umap'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'

# %%
sc.pl.umap(aging_data, color='afca_annotation_broad')
# Out:
# /home/ouyangkang/software/anaconda3/envs/scRNA/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
reproductive_data = aging_data[np.in1d(aging_data.obs['afca_annotation_broad'], 'female reproductive system')]
reproductive_data
# Out:
# View of AnnData object with n_obs × n_vars = 29219 × 15992
#     obs: 'tissue', 'sex', 'age', 'sex_age', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'log1p_total_counts_mt', 'dataset', 'fca_annotation', 'afca_annotation', 'afca_annotation_broad'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'age_colors', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'sex_colors', 'tissue_colors', 'tsne', 'umap', 'afca_annotation_broad_colors'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'

# %%
sc.pl.umap(reproductive_data, color='afca_annotation')
# Out:
# /home/ouyangkang/software/anaconda3/envs/scRNA/lib/python3.8/site-packages/scanpy/plotting/_utils.py:430: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + '_colors'] = colors_list
# /home/ouyangkang/software/anaconda3/envs/scRNA/lib/python3.8/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
